# %%
import pandas as pd

# %%
file_path = '/content/merged_Data_final_v2.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# ### 정당, 최종학력, 지역 포함

# %%
# Final Education, Region 정보

# Bachelor's: 학사 학위
# Master's: 석사 학위
# PhD: 박사 학위
# JD: 법무박사 학위
# None: 학위 없음

presidents_data = {
    1916: {"Name": "Woodrow Wilson", "Final Education": "PhD", "Region": "Virginia", "Party": "Democratic"},
    1920: {"Name": "Warren G. Harding", "Final Education": "Bachelor's", "Region": "Ohio", "Party": "Republican"},
    1924: {"Name": "Calvin Coolidge", "Final Education": "Bachelor's", "Region": "Vermont", "Party": "Republican"},
    1928: {"Name": "Herbert Hoover", "Final Education": "Bachelor's", "Region": "Iowa", "Party": "Republican"},
    1932: {"Name": "Franklin D. Roosevelt", "Final Education": "Bachelor's", "Region": "New York", "Party": "Democratic"},
    1936: {"Name": "Franklin D. Roosevelt", "Final Education": "Bachelor's", "Region": "New York", "Party": "Democratic"},
    1940: {"Name": "Franklin D. Roosevelt", "Final Education": "Bachelor's", "Region": "New York", "Party": "Democratic"},
    1944: {"Name": "Franklin D. Roosevelt", "Final Education": "Bachelor's", "Region": "New York", "Party": "Democratic"},
    1948: {"Name": "Harry S. Truman", "Final Education": "None", "Region": "Missouri", "Party": "Democratic"},
    1952: {"Name": "Dwight D. Eisenhower", "Final Education": "Bachelor's", "Region": "Texas", "Party": "Republican"},
    1956: {"Name": "Dwight D. Eisenhower", "Final Education": "Bachelor's", "Region": "Texas", "Party": "Republican"},
    1960: {"Name": "John F. Kennedy", "Final Education": "Bachelor's", "Region": "Massachusetts", "Party": "Democratic"},
    1964: {"Name": "Lyndon B. Johnson", "Final Education": "Bachelor's", "Region": "Texas", "Party": "Democratic"},
    1968: {"Name": "Richard Nixon", "Final Education": "JD", "Region": "California", "Party": "Republican"},
    1972: {"Name": "Richard Nixon", "Final Education": "JD", "Region": "California", "Party": "Republican"},
    1976: {"Name": "Jimmy Carter", "Final Education": "Bachelor's", "Region": "Georgia", "Party": "Democratic"},
    1980: {"Name": "Ronald Reagan", "Final Education": "Bachelor's", "Region": "Illinois", "Party": "Republican"},
    1984: {"Name": "Ronald Reagan", "Final Education": "Bachelor's", "Region": "Illinois", "Party": "Republican"},
    1988: {"Name": "George H. W. Bush", "Final Education": "Bachelor's", "Region": "Massachusetts", "Party": "Republican"},
    1992: {"Name": "Bill Clinton", "Final Education": "JD", "Region": "Arkansas", "Party": "Democratic"},
    1996: {"Name": "Bill Clinton", "Final Education": "JD", "Region": "Arkansas", "Party": "Democratic"},
    2000: {"Name": "George W. Bush", "Final Education": "Master's", "Region": "Texas", "Party": "Republican"},
    2004: {"Name": "George W. Bush", "Final Education": "Master's", "Region": "Texas", "Party": "Republican"},
    2008: {"Name": "Barack Obama", "Final Education": "JD", "Region": "Hawaii", "Party": "Democratic"},
    2012: {"Name": "Barack Obama", "Final Education": "JD", "Region": "Hawaii", "Party": "Democratic"},
    2016: {"Name": "Donald Trump", "Final Education": "Bachelor's", "Region": "New York", "Party": "Republican"},
    2020: {"Name": "Joe Biden", "Final Education": "JD", "Region": "Pennsylvania", "Party": "Democratic"}
}

# %%
for year, info in presidents_data.items():
    df.loc[df['Year'] == year, ['Name', 'Party', 'Final Education', 'Region']] = info['Name'], info['Party'], info['Final Education'], info['Region']

# %%
df.drop('Name', axis=1, inplace=True)

# %%
output_file_path = '/content/add_Final Education_Region_1.csv'
df.to_csv(output_file_path, index=False)

# %%
file_path = '/content/add_Final Education_Region_1.csv'
df = pd.read_csv(file_path)

# %%
# 후보자 추가

# c = candidate

candidates_data = {
    1916: {"c_Name": "Charles Evans Hughes", "c_Final_Education": "JD", "c_Region": "New York", "c_Party": "Republican"},
    1920: {"c_Name": "James M. Cox", "c_Final_Education": "None", "c_Region": "Ohio", "c_Party": "Democratic"},
    1924: {"c_Name": "John W. Davis", "c_Final_Education": "Bachelor's", "c_Region": "West Virginia", "c_Party": "Democratic"},
    1928: {"c_Name": "Al Smith", "c_Final_Education": "None", "c_Region": "New York", "c_Party": "Democratic"},
    1932: {"c_Name": "Herbert Hoover", "c_Final_Education": "Bachelor's", "c_Region": "Iowa", "c_Party": "Republican"},
    1936: {"c_Name": "Alf Landon", "c_Final_Education": "Bachelor's", "c_Region": "Kansas", "c_Party": "Republican"},
    1940: {"c_Name": "Wendell Willkie", "c_Final_Education": "Bachelor's", "c_Region": "Indiana", "c_Party": "Republican"},
    1944: {"c_Name": "Thomas E. Dewey", "c_Final_Education": "JD", "c_Region": "New York", "c_Party": "Republican"},
    1948: {"c_Name": "Thomas E. Dewey", "c_Final_Education": "JD", "c_Region": "New York", "c_Party": "Republican"},
    1952: {"c_Name": "Adlai Stevenson", "c_Final_Education": "JD", "c_Region": "Illinois", "c_Party": "Democratic"},
    1956: {"c_Name": "Adlai Stevenson", "c_Final_Education": "JD", "c_Region": "Illinois", "c_Party": "Democratic"},
    1960: {"c_Name": "Richard Nixon", "c_Final_Education": "JD", "c_Region": "California", "c_Party": "Republican"},
    1964: {"c_Name": "Barry Goldwater", "c_Final_Education": "None", "c_Region": "Arizona", "c_Party": "Republican"},
    1968: {"c_Name": "Hubert Humphrey", "c_Final_Education": "Master's", "c_Region": "South Dakota", "c_Party": "Democratic"},
    1972: {"c_Name": "George McGovern", "c_Final_Education": "PhD", "c_Region": "South Dakota", "c_Party": "Democratic"},
    1976: {"c_Name": "Gerald Ford", "c_Final_Education": "JD", "c_Region": "Michigan", "c_Party": "Republican"},
    1980: {"c_Name": "Jimmy Carter", "c_Final_Education": "Bachelor's", "c_Region": "Georgia", "c_Party": "Democratic"},
    1984: {"c_Name": "Walter Mondale", "c_Final_Education": "JD", "c_Region": "Minnesota", "c_Party": "Democratic"},
    1988: {"c_Name": "Michael Dukakis", "c_Final_Education": "JD", "c_Region": "Massachusetts", "c_Party": "Democratic"},
    1992: {"c_Name": "George H. W. Bush", "c_Final_Education": "Bachelor's", "c_Region": "Massachusetts", "c_Party": "Republican"},
    1996: {"c_Name": "Bob Dole", "c_Final_Education": "JD", "c_Region": "Kansas", "c_Party": "Republican"},
    2000: {"c_Name": "Al Gore", "c_Final_Education": "Bachelor's", "c_Region": "Tennessee", "c_Party": "Democratic"},
    2004: {"c_Name": "John Kerry", "c_Final_Education": "JD", "c_Region": "Massachusetts", "c_Party": "Democratic"},
    2008: {"c_Name": "John McCain", "c_Final_Education": "Bachelor's", "c_Region": "Arizona", "c_Party": "Republican"},
    2012: {"c_Name": "Mitt Romney", "c_Final_Education": "JD", "c_Region": "Michigan", "c_Party": "Republican"},
    2016: {"c_Name": "Hillary Clinton", "c_Final_Education": "JD", "c_Region": "Illinois", "c_Party": "Democratic"},
    2020: {"c_Name": "Donald Trump", "c_Final_Education": "Bachelor's", "c_Region": "New York", "c_Party": "Republican"}
}

# %%
# 해당 연도 데이터 추가
for year, info in candidates_data.items():
    df.loc[df['Year'] == year, ['c_Party','c_Final_Education', 'c_Region']] = info['c_Party'], info['c_Final_Education'], info['c_Region']

# %%
df.head()
# Out:
#    Year  Approval_Rating        CPI     GDP  Employment status  Current_Party  \
# 0  1913             50.0   9.883333  733625                4.4              0
# 1  1914             50.0  10.016667  677455                8.0              0
# 2  1915             50.0  10.108333  695924                9.7              0
# 3  1916             50.0  10.883333  792425                4.8              0
# 4  1917             50.0  12.825000  772825                4.8              0
#
#    Party_Republican       Party Final Education    Region     c_Party  \
# 0                 0         NaN             NaN       NaN         NaN
# 1                 0         NaN             NaN       NaN         NaN
# 2                 0         NaN             NaN       NaN         NaN
# 3                 0  Democratic             PhD  Virginia  Republican
# 4                 0         NaN             NaN       NaN         NaN
#
#   c_Final_Education  c_Region
# 0               NaN       NaN
# ...

# %%
output_file_path = '/content/add_merged_data.csv'
df.to_csv(output_file_path, index=False)

# %% [markdown]
# ### 정당, 최종학력, 지역, 전공 포함

# %%
presidents_data = {
    1916: {"Name": "Woodrow Wilson", "Final Education": "PhD", "Region": "Virginia", "Party": "Democratic", "Major": "Political Science"},
    1920: {"Name": "Warren G. Harding", "Final Education": "Bachelor's", "Region": "Ohio", "Party": "Republican", "Major": "Literature"},
    1924: {"Name": "Calvin Coolidge", "Final Education": "Bachelor's", "Region": "Vermont", "Party": "Republican", "Major": "Law"},
    1928: {"Name": "Herbert Hoover", "Final Education": "Bachelor's", "Region": "Iowa", "Party": "Republican", "Major": "Geology"},
    1932: {"Name": "Franklin D. Roosevelt", "Final Education": "Bachelor's", "Region": "New York", "Party": "Democratic", "Major": "History"},
    1936: {"Name": "Franklin D. Roosevelt", "Final Education": "Bachelor's", "Region": "New York", "Party": "Democratic", "Major": "History"},
    1940: {"Name": "Franklin D. Roosevelt", "Final Education": "Bachelor's", "Region": "New York", "Party": "Democratic", "Major": "History"},
    1944: {"Name": "Franklin D. Roosevelt", "Final Education": "Bachelor's", "Region": "New York", "Party": "Democratic", "Major": "History"},
    1948: {"Name": "Harry S. Truman", "Final Education": "None", "Region": "Missouri", "Party": "Democratic", "Major": "Law"},
    1952: {"Name": "Dwight D. Eisenhower", "Final Education": "Bachelor's", "Region": "Texas", "Party": "Republican", "Major": "Military Engineering"},
    1956: {"Name": "Dwight D. Eisenhower", "Final Education": "Bachelor's", "Region": "Texas", "Party": "Republican", "Major": "Military Engineering"},
    1960: {"Name": "John F. Kennedy", "Final Education": "Bachelor's", "Region": "Massachusetts", "Party": "Democratic", "Major": "International Affairs"},
    1964: {"Name": "Lyndon B. Johnson", "Final Education": "Bachelor's", "Region": "Texas", "Party": "Democratic", "Major": "Education"},
    1968: {"Name": "Richard Nixon", "Final Education": "JD", "Region": "California", "Party": "Republican", "Major": "Law"},
    1972: {"Name": "Richard Nixon", "Final Education": "JD", "Region": "California", "Party": "Republican", "Major": "Law"},
    1976: {"Name": "Jimmy Carter", "Final Education": "Bachelor's", "Region": "Georgia", "Party": "Democratic", "Major": "Naval Science Engineering"},
    1980: {"Name": "Ronald Reagan", "Final Education": "Bachelor's", "Region": "Illinois", "Party": "Republican", "Major": "Economics and Sociology"},
    1984: {"Name": "Ronald Reagan", "Final Education": "Bachelor's", "Region": "Illinois", "Party": "Republican", "Major": "Economics and Sociology"},
    1988: {"Name": "George H. W. Bush", "Final Education": "Bachelor's", "Region": "Massachusetts", "Party": "Republican", "Major": "Economics"},
    1992: {"Name": "Bill Clinton", "Final Education": "JD", "Region": "Arkansas", "Party": "Democratic", "Major": "Law"},
    1996: {"Name": "Bill Clinton", "Final Education": "JD", "Region": "Arkansas", "Party": "Democratic", "Major": "Law"},
    2000: {"Name": "George W. Bush", "Final Education": "Master's", "Region": "Texas", "Party": "Republican", "Major": "Business Administration"},
    2004: {"Name": "George W. Bush", "Final Education": "Master's", "Region": "Texas", "Party": "Republican", "Major": "Business Administration"},
    2008: {"Name": "Barack Obama", "Final Education": "JD", "Region": "Hawaii", "Party": "Democratic", "Major": "Law"},
    2012: {"Name": "Barack Obama", "Final Education": "JD", "Region": "Hawaii", "Party": "Democratic", "Major": "Law"},
    2016: {"Name": "Donald Trump", "Final Education": "Bachelor's", "Region": "New York", "Party": "Republican", "Major": "Economics"},
    2020: {"Name": "Joe Biden", "Final Education": "JD", "Region": "Pennsylvania", "Party": "Democratic", "Major": "Law"}
}

# %%
for year, info in presidents_data.items():
    df.loc[df['Year'] == year, ['Name', 'Party', 'Final Education', 'Region','Major']] = info['Name'], info['Party'], info['Final Education'], info['Region'], info['Major']

# %%
df.drop('Name', axis=1, inplace=True)

# %%
output_file_path = '/content/add_Final Education_Region_2.csv'
df.to_csv(output_file_path, index=False)
