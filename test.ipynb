# %%
import nomination_crawler

# %%
nomination_crawler.crawl_nomination_speech(save=True)
# Out:
# 100%|██████████| 86/86 [01:39<00:00,  1.15s/it]
#                 name                date  \
# 0    Joseph R. Biden     August 20, 2020
# 1    Hillary Clinton       July 28, 2016
# 2       Barack Obama  September 06, 2012
# 3       Barack Obama     August 28, 2008
# 4      John F. Kerry       July 29, 2004
# ..               ...                 ...
# 80  Ulysses S. Grant       June 10, 1872
# 81  Ulysses S. Grant        May 29, 1868
# 82  Ulysses S. Grant        May 29, 1868
# 83   Abraham Lincoln       June 27, 1864
# 84   Abraham Lincoln        May 19, 1860
#
#                                                speech
# 0   [Good evening., Ella Baker, a giant of the civ...
# 1   [Thank you all very, very much! Thank you for ...
# 2   [The First Lady. Thank you so much. Tonight I ...
# 3   [To Chairman Dean and my great friend Dick Dur...
# 4   [I'm John Kerry and I'm reporting for duty., W...
# ..                                                ...
# ...
